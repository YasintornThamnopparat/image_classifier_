# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import torch
from torch import nn,optim
import torch.nn.functional as F
from torchvision import models,datasets,transforms
import pandas as pd
from PIL import Image
import numpy as np

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                      transforms.RandomResizedCrop(224),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.229,0.224,0.225],
                                                          [0.485,0.456,0.406])])
valid_transforms = transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.229,0.224,0.225],
                                                          [0.485,0.456,0.406])])
test_transforms = transforms.Compose([transforms.Resize(255),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.229,0.224,0.225],
                                                          [0.485,0.456,0.406])])

# TODO: Load the datasets with ImageFolder
train_data = datasets.ImageFolder(train_dir,transform = train_transforms)
valid_data = datasets.ImageFolder(valid_dir,transform = valid_transforms)
test_data = datasets.ImageFolder(test_dir,transform = test_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
trainloader = torch.utils.data.DataLoader(train_data,batch_size=64,shuffle=True)
validloader = torch.utils.data.DataLoader(valid_data,batch_size=64)
testloader = torch.utils.data.DataLoader(test_data,batch_size=64)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network
model = models.vgg16(pretrained = True)
model
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [01:21<00:00, 6791490.89it/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
#freeze parameters
for param in model.parameters() :
    param.requires_grad = False

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Build a feed-forward network
from collections import OrderedDict

model.classifier = nn.Sequential(OrderedDict([
                            ('fc1',nn.Linear(25088,4096)),
                            ('relu1',nn.ReLU()),
                            ('dropout1',nn.Dropout(p=0.3)),
                            ('fc2',nn.Linear(4096,4096)),
                            ('relu2',nn.ReLU()),
                            ('dropout2',nn.Dropout(p=0.3)),
                            ('fc3',nn.Linear(4096,1000)),
                            ('relu3',nn.ReLU()),
                            ('droupout3',nn.Dropout(p=0.3)),
                            ('fc4',nn.Linear(1000,102)),
                            ('output',nn.LogSoftmax(dim=1))]))


criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(),lr = 0.002)

model.to(device)
epochs =15

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
epochs = 15
steps = 0
running_loss = 0
print_every = 5

for epoch in range(epochs) :
    for images,labels in trainloader :
        steps +=1
        images,labels = images.to(device),labels.to(device)
        
        optimizer.zero_grad()
        log_ps = model.forward(images)
        loss = criterion(log_ps,labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        
        if steps % print_every == 0 :
            valid_loss = 0
            accuracy = 0
            model.eval()
            with torch.no_grad() :
                for images,labels in validloader :
                    images,labels = images.to(device),labels.to(device)
                    logps = model.forward(images)
                    batch_loss = criterion(logps,labels)
                    valid_loss += batch_loss.item()
                    
                    ps = torch.exp(logps)
                    top_p,top_class = ps.topk(1,dim=1)
                    equal = top_class==labels.view(*top_class.shape)
                    accuracy += torch.mean(equal.type(torch.FloatTensor)).item()
                    
            print(f'Epoch : {epoch+1}/{epochs}..'
                 f'Train loss : {running_loss/print_every:.3f}..'
                 f'Validation loss : {valid_loss/len(validloader):.3f}..'
                 f'Test accuracy : {accuracy/len(validloader):.3f}')
            running_loss = 0
            model.train()
# Out:
# Epoch : 1/15..Train loss : 11.547..Validation loss : 4.605..Test accuracy : 0.034
# Epoch : 1/15..Train loss : 4.641..Validation loss : 4.559..Test accuracy : 0.022
# Epoch : 1/15..Train loss : 4.573..Validation loss : 4.521..Test accuracy : 0.056
# Epoch : 1/15..Train loss : 4.488..Validation loss : 4.363..Test accuracy : 0.069
# Epoch : 1/15..Train loss : 4.457..Validation loss : 4.250..Test accuracy : 0.079
# Epoch : 1/15..Train loss : 4.323..Validation loss : 4.179..Test accuracy : 0.078
# Epoch : 1/15..Train loss : 4.399..Validation loss : 4.094..Test accuracy : 0.119
# Epoch : 1/15..Train loss : 4.331..Validation loss : 4.023..Test accuracy : 0.114
# Epoch : 1/15..Train loss : 4.145..Validation loss : 3.847..Test accuracy : 0.143
# Epoch : 1/15..Train loss : 4.044..Validation loss : 3.735..Test accuracy : 0.147
# Epoch : 1/15..Train loss : 3.963..Validation loss : 3.608..Test accuracy : 0.187
# Epoch : 1/15..Train loss : 3.802..Validation loss : 3.399..Test accuracy : 0.167
# Epoch : 1/15..Train loss : 3.704..Validation loss : 3.192..Test accuracy : 0.243
# Epoch : 1/15..Train loss : 3.678..Validation loss : 3.133..Test accuracy : 0.237
# Epoch : 1/15..Train loss : 3.641..Validation loss : 3.100..Test accuracy : 0.215
# Epoch : 1/15..Train loss : 3.701..Validation loss : 3.077..Test accuracy : 0.233
# Epoch : 1/15..Train loss : 3.358..Validation loss : 2.959..Test accuracy : 0.266
# Epoch : 1/15..Train loss : 3.559..Validation loss : 2.912..Test accuracy : 0.283
# Epoch : 1/15..Train loss : 3.484..Validation loss : 2.822..Test accuracy : 0.288
# Epoch : 1/15..Train loss : 3.258..Validation loss : 2.863..Test accuracy : 0.259
# Epoch : 2/15..Train loss : 3.109..Validation loss : 2.786..Test accuracy : 0.287
# Epoch : 2/15..Train loss : 3.249..Validation loss : 2.651..Test accuracy : 0.318
# Epoch : 2/15..Train loss : 3.387..Validation loss : 2.642..Test accuracy : 0.313
# Epoch : 2/15..Train loss : 3.161..Validation loss : 2.528..Test accuracy : 0.351
# Epoch : 2/15..Train loss : 3.303..Validation loss : 2.566..Test accuracy : 0.335
# Epoch : 2/15..Train loss : 3.266..Validation loss : 2.583..Test accuracy : 0.356
# Epoch : 2/15..Train loss : 3.063..Validation loss : 2.566..Test accuracy : 0.333
# Epoch : 2/15..Train loss : 3.167..Validation loss : 2.417..Test accuracy : 0.352
# Epoch : 2/15..Train loss : 3.064..Validation loss : 2.336..Test accuracy : 0.379
# Epoch : 2/15..Train loss : 3.076..Validation loss : 2.306..Test accuracy : 0.391
# Epoch : 2/15..Train loss : 3.045..Validation loss : 2.302..Test accuracy : 0.393
# Epoch : 2/15..Train loss : 2.987..Validation loss : 2.204..Test accuracy : 0.403
# Epoch : 2/15..Train loss : 3.043..Validation loss : 2.258..Test accuracy : 0.394
# Epoch : 2/15..Train loss : 2.853..Validation loss : 2.215..Test accuracy : 0.413
# Epoch : 2/15..Train loss : 3.009..Validation loss : 2.137..Test accuracy : 0.443
# Epoch : 2/15..Train loss : 3.035..Validation loss : 2.168..Test accuracy : 0.408
# Epoch : 2/15..Train loss : 3.033..Validation loss : 2.094..Test accuracy : 0.427
# Epoch : 2/15..Train loss : 2.936..Validation loss : 2.061..Test accuracy : 0.432
# Epoch : 2/15..Train loss : 2.826..Validation loss : 2.139..Test accuracy : 0.416
# Epoch : 2/15..Train loss : 2.730..Validation loss : 2.068..Test accuracy : 0.430
# Epoch : 2/15..Train loss : 2.859..Validation loss : 1.992..Test accuracy : 0.443
# Epoch : 3/15..Train loss : 2.743..Validation loss : 2.082..Test accuracy : 0.432
# Epoch : 3/15..Train loss : 2.672..Validation loss : 2.041..Test accuracy : 0.477
# Epoch : 3/15..Train loss : 2.908..Validation loss : 2.083..Test accuracy : 0.462
# Epoch : 3/15..Train loss : 2.713..Validation loss : 2.085..Test accuracy : 0.439
# Epoch : 3/15..Train loss : 2.859..Validation loss : 1.945..Test accuracy : 0.493
# Epoch : 3/15..Train loss : 2.931..Validation loss : 1.955..Test accuracy : 0.454
# Epoch : 3/15..Train loss : 2.794..Validation loss : 1.956..Test accuracy : 0.457
# Epoch : 3/15..Train loss : 2.726..Validation loss : 1.949..Test accuracy : 0.462
# Epoch : 3/15..Train loss : 2.715..Validation loss : 2.003..Test accuracy : 0.477
# Epoch : 3/15..Train loss : 2.743..Validation loss : 1.821..Test accuracy : 0.505
# Epoch : 3/15..Train loss : 2.604..Validation loss : 1.864..Test accuracy : 0.486
# Epoch : 3/15..Train loss : 2.722..Validation loss : 1.930..Test accuracy : 0.466
# Epoch : 3/15..Train loss : 2.544..Validation loss : 1.894..Test accuracy : 0.464
# Epoch : 3/15..Train loss : 2.622..Validation loss : 1.934..Test accuracy : 0.485
# Epoch : 3/15..Train loss : 2.777..Validation loss : 1.862..Test accuracy : 0.491
# Epoch : 3/15..Train loss : 2.712..Validation loss : 1.928..Test accuracy : 0.492
# Epoch : 3/15..Train loss : 2.779..Validation loss : 1.902..Test accuracy : 0.489
# Epoch : 3/15..Train loss : 2.750..Validation loss : 1.800..Test accuracy : 0.534
# Epoch : 3/15..Train loss : 2.801..Validation loss : 1.840..Test accuracy : 0.526
# Epoch : 3/15..Train loss : 2.699..Validation loss : 1.735..Test accuracy : 0.549
# Epoch : 4/15..Train loss : 2.456..Validation loss : 1.754..Test accuracy : 0.521
# Epoch : 4/15..Train loss : 2.567..Validation loss : 1.733..Test accuracy : 0.547
# Epoch : 4/15..Train loss : 2.837..Validation loss : 1.816..Test accuracy : 0.502
# Epoch : 4/15..Train loss : 2.720..Validation loss : 1.855..Test accuracy : 0.528
# Epoch : 4/15..Train loss : 2.489..Validation loss : 1.703..Test accuracy : 0.542
# Epoch : 4/15..Train loss : 2.519..Validation loss : 1.698..Test accuracy : 0.545
# Epoch : 4/15..Train loss : 2.634..Validation loss : 1.661..Test accuracy : 0.573
# Epoch : 4/15..Train loss : 2.610..Validation loss : 1.775..Test accuracy : 0.545
# Epoch : 4/15..Train loss : 2.680..Validation loss : 1.776..Test accuracy : 0.543
# Epoch : 4/15..Train loss : 2.670..Validation loss : 1.843..Test accuracy : 0.527
# Epoch : 4/15..Train loss : 2.617..Validation loss : 1.737..Test accuracy : 0.516
# Epoch : 4/15..Train loss : 2.503..Validation loss : 1.707..Test accuracy : 0.517
# Epoch : 4/15..Train loss : 2.391..Validation loss : 1.624..Test accuracy : 0.548
# Epoch : 4/15..Train loss : 2.459..Validation loss : 1.652..Test accuracy : 0.537
# Epoch : 4/15..Train loss : 2.486..Validation loss : 1.673..Test accuracy : 0.537
# Epoch : 4/15..Train loss : 2.766..Validation loss : 1.675..Test accuracy : 0.527
# Epoch : 4/15..Train loss : 2.514..Validation loss : 1.637..Test accuracy : 0.551
# Epoch : 4/15..Train loss : 2.671..Validation loss : 1.578..Test accuracy : 0.560
# Epoch : 4/15..Train loss : 2.625..Validation loss : 1.648..Test accuracy : 0.557
# Epoch : 4/15..Train loss : 2.793..Validation loss : 1.733..Test accuracy : 0.525
# Epoch : 4/15..Train loss : 2.547..Validation loss : 1.614..Test accuracy : 0.560
# Epoch : 5/15..Train loss : 2.443..Validation loss : 1.624..Test accuracy : 0.537
# Epoch : 5/15..Train loss : 2.529..Validation loss : 1.679..Test accuracy : 0.538
# Epoch : 5/15..Train loss : 2.831..Validation loss : 1.771..Test accuracy : 0.509
# Epoch : 5/15..Train loss : 2.525..Validation loss : 1.761..Test accuracy : 0.512
# Epoch : 5/15..Train loss : 2.637..Validation loss : 1.721..Test accuracy : 0.533
# Epoch : 5/15..Train loss : 2.309..Validation loss : 1.759..Test accuracy : 0.536
# Epoch : 5/15..Train loss : 2.772..Validation loss : 1.742..Test accuracy : 0.546
# Epoch : 5/15..Train loss : 2.481..Validation loss : 1.625..Test accuracy : 0.561
# Epoch : 5/15..Train loss : 2.425..Validation loss : 1.584..Test accuracy : 0.569
# Epoch : 5/15..Train loss : 2.392..Validation loss : 1.535..Test accuracy : 0.595
# Epoch : 5/15..Train loss : 2.457..Validation loss : 1.578..Test accuracy : 0.569
# Epoch : 5/15..Train loss : 2.468..Validation loss : 1.546..Test accuracy : 0.552
# Epoch : 5/15..Train loss : 2.558..Validation loss : 1.579..Test accuracy : 0.552
# Epoch : 5/15..Train loss : 2.504..Validation loss : 1.621..Test accuracy : 0.563
# Epoch : 5/15..Train loss : 2.516..Validation loss : 1.599..Test accuracy : 0.570
# Epoch : 5/15..Train loss : 2.446..Validation loss : 1.558..Test accuracy : 0.580
# Epoch : 5/15..Train loss : 2.790..Validation loss : 1.511..Test accuracy : 0.587
# Epoch : 5/15..Train loss : 2.448..Validation loss : 1.633..Test accuracy : 0.575
# Epoch : 5/15..Train loss : 2.575..Validation loss : 1.572..Test accuracy : 0.584
# Epoch : 5/15..Train loss : 2.432..Validation loss : 1.579..Test accuracy : 0.576
# Epoch : 5/15..Train loss : 2.593..Validation loss : 1.592..Test accuracy : 0.575
# Epoch : 6/15..Train loss : 2.312..Validation loss : 1.597..Test accuracy : 0.529
# Epoch : 6/15..Train loss : 2.534..Validation loss : 1.556..Test accuracy : 0.572
# Epoch : 6/15..Train loss : 2.366..Validation loss : 1.530..Test accuracy : 0.588
# Epoch : 6/15..Train loss : 2.551..Validation loss : 1.487..Test accuracy : 0.612
# Epoch : 6/15..Train loss : 2.287..Validation loss : 1.530..Test accuracy : 0.599
# Epoch : 6/15..Train loss : 2.497..Validation loss : 1.479..Test accuracy : 0.609
# Epoch : 6/15..Train loss : 2.287..Validation loss : 1.424..Test accuracy : 0.621
# Epoch : 6/15..Train loss : 2.277..Validation loss : 1.483..Test accuracy : 0.585
# Epoch : 6/15..Train loss : 2.338..Validation loss : 1.546..Test accuracy : 0.571
# Epoch : 6/15..Train loss : 2.353..Validation loss : 1.560..Test accuracy : 0.573
# Epoch : 6/15..Train loss : 2.340..Validation loss : 1.505..Test accuracy : 0.609
# Epoch : 6/15..Train loss : 2.577..Validation loss : 1.503..Test accuracy : 0.597
# Epoch : 6/15..Train loss : 2.324..Validation loss : 1.517..Test accuracy : 0.597
# Epoch : 6/15..Train loss : 2.626..Validation loss : 1.502..Test accuracy : 0.614
# Epoch : 6/15..Train loss : 2.268..Validation loss : 1.499..Test accuracy : 0.595
# Epoch : 6/15..Train loss : 2.368..Validation loss : 1.501..Test accuracy : 0.577
# Epoch : 6/15..Train loss : 2.467..Validation loss : 1.483..Test accuracy : 0.582
# Epoch : 6/15..Train loss : 2.504..Validation loss : 1.515..Test accuracy : 0.573
# Epoch : 6/15..Train loss : 2.416..Validation loss : 1.514..Test accuracy : 0.568
# Epoch : 6/15..Train loss : 2.605..Validation loss : 1.491..Test accuracy : 0.584
# Epoch : 7/15..Train loss : 2.594..Validation loss : 1.505..Test accuracy : 0.592
# Epoch : 7/15..Train loss : 2.364..Validation loss : 1.521..Test accuracy : 0.595
# Epoch : 7/15..Train loss : 2.667..Validation loss : 1.429..Test accuracy : 0.605
# Epoch : 7/15..Train loss : 2.584..Validation loss : 1.443..Test accuracy : 0.606
# Epoch : 7/15..Train loss : 2.285..Validation loss : 1.442..Test accuracy : 0.617
# Epoch : 7/15..Train loss : 2.503..Validation loss : 1.444..Test accuracy : 0.605
# Epoch : 7/15..Train loss : 2.359..Validation loss : 1.405..Test accuracy : 0.631
# Epoch : 7/15..Train loss : 2.524..Validation loss : 1.486..Test accuracy : 0.603
# Epoch : 7/15..Train loss : 2.370..Validation loss : 1.429..Test accuracy : 0.616
# Epoch : 7/15..Train loss : 2.475..Validation loss : 1.537..Test accuracy : 0.584
# Epoch : 7/15..Train loss : 2.403..Validation loss : 1.527..Test accuracy : 0.588
# Epoch : 7/15..Train loss : 2.559..Validation loss : 1.456..Test accuracy : 0.606
# Epoch : 7/15..Train loss : 2.492..Validation loss : 1.536..Test accuracy : 0.609
# Epoch : 7/15..Train loss : 2.326..Validation loss : 1.567..Test accuracy : 0.585
# Epoch : 7/15..Train loss : 2.330..Validation loss : 1.471..Test accuracy : 0.630
# Epoch : 7/15..Train loss : 2.662..Validation loss : 1.500..Test accuracy : 0.609
# Epoch : 7/15..Train loss : 2.327..Validation loss : 1.495..Test accuracy : 0.608
# Epoch : 7/15..Train loss : 2.282..Validation loss : 1.436..Test accuracy : 0.616
# Epoch : 7/15..Train loss : 2.451..Validation loss : 1.473..Test accuracy : 0.585
# Epoch : 7/15..Train loss : 2.495..Validation loss : 1.459..Test accuracy : 0.593
# Epoch : 7/15..Train loss : 2.323..Validation loss : 1.490..Test accuracy : 0.610
# Epoch : 8/15..Train loss : 2.503..Validation loss : 1.538..Test accuracy : 0.591
# Epoch : 8/15..Train loss : 2.385..Validation loss : 1.514..Test accuracy : 0.595
# Epoch : 8/15..Train loss : 2.506..Validation loss : 1.515..Test accuracy : 0.585
# Epoch : 8/15..Train loss : 2.311..Validation loss : 1.465..Test accuracy : 0.596
# Epoch : 8/15..Train loss : 2.324..Validation loss : 1.448..Test accuracy : 0.598
# Epoch : 8/15..Train loss : 2.470..Validation loss : 1.465..Test accuracy : 0.595
# Epoch : 8/15..Train loss : 2.340..Validation loss : 1.446..Test accuracy : 0.599
# Epoch : 8/15..Train loss : 2.218..Validation loss : 1.410..Test accuracy : 0.614
# Epoch : 8/15..Train loss : 2.633..Validation loss : 1.398..Test accuracy : 0.620
# Epoch : 8/15..Train loss : 2.534..Validation loss : 1.402..Test accuracy : 0.604
# Epoch : 8/15..Train loss : 2.400..Validation loss : 1.450..Test accuracy : 0.613
# Epoch : 8/15..Train loss : 2.470..Validation loss : 1.509..Test accuracy : 0.607
# Epoch : 8/15..Train loss : 2.533..Validation loss : 1.431..Test accuracy : 0.638
# Epoch : 8/15..Train loss : 2.429..Validation loss : 1.451..Test accuracy : 0.606
# Epoch : 8/15..Train loss : 2.250..Validation loss : 1.385..Test accuracy : 0.622
# Epoch : 8/15..Train loss : 2.234..Validation loss : 1.378..Test accuracy : 0.622
# Epoch : 8/15..Train loss : 2.395..Validation loss : 1.390..Test accuracy : 0.619
# Epoch : 8/15..Train loss : 2.209..Validation loss : 1.403..Test accuracy : 0.636
# Epoch : 8/15..Train loss : 2.568..Validation loss : 1.454..Test accuracy : 0.618
# Epoch : 8/15..Train loss : 2.189..Validation loss : 1.452..Test accuracy : 0.621
# Epoch : 9/15..Train loss : 2.265..Validation loss : 1.421..Test accuracy : 0.614
# Epoch : 9/15..Train loss : 2.413..Validation loss : 1.368..Test accuracy : 0.633
# Epoch : 9/15..Train loss : 2.236..Validation loss : 1.298..Test accuracy : 0.661
# Epoch : 9/15..Train loss : 2.371..Validation loss : 1.301..Test accuracy : 0.644
# Epoch : 9/15..Train loss : 2.495..Validation loss : 1.379..Test accuracy : 0.638
# Epoch : 9/15..Train loss : 2.442..Validation loss : 1.396..Test accuracy : 0.637
# Epoch : 9/15..Train loss : 2.208..Validation loss : 1.381..Test accuracy : 0.635
# Epoch : 9/15..Train loss : 2.157..Validation loss : 1.345..Test accuracy : 0.649
# Epoch : 9/15..Train loss : 2.421..Validation loss : 1.282..Test accuracy : 0.668
# Epoch : 9/15..Train loss : 2.093..Validation loss : 1.274..Test accuracy : 0.642
# Epoch : 9/15..Train loss : 2.191..Validation loss : 1.228..Test accuracy : 0.649
# Epoch : 9/15..Train loss : 2.600..Validation loss : 1.291..Test accuracy : 0.647
# Epoch : 9/15..Train loss : 2.453..Validation loss : 1.470..Test accuracy : 0.610
# Epoch : 9/15..Train loss : 2.458..Validation loss : 1.362..Test accuracy : 0.629
# Epoch : 9/15..Train loss : 2.656..Validation loss : 1.315..Test accuracy : 0.659
# Epoch : 9/15..Train loss : 2.397..Validation loss : 1.357..Test accuracy : 0.632
# Epoch : 9/15..Train loss : 2.439..Validation loss : 1.397..Test accuracy : 0.626
# Epoch : 9/15..Train loss : 2.679..Validation loss : 1.428..Test accuracy : 0.652
# Epoch : 9/15..Train loss : 2.265..Validation loss : 1.413..Test accuracy : 0.638
# Epoch : 9/15..Train loss : 2.274..Validation loss : 1.410..Test accuracy : 0.641
# Epoch : 9/15..Train loss : 2.425..Validation loss : 1.431..Test accuracy : 0.628
# Epoch : 10/15..Train loss : 2.372..Validation loss : 1.351..Test accuracy : 0.657
# Epoch : 10/15..Train loss : 2.517..Validation loss : 1.305..Test accuracy : 0.660
# Epoch : 10/15..Train loss : 2.303..Validation loss : 1.323..Test accuracy : 0.648
# Epoch : 10/15..Train loss : 2.361..Validation loss : 1.327..Test accuracy : 0.637
# Epoch : 10/15..Train loss : 2.368..Validation loss : 1.292..Test accuracy : 0.642
# Epoch : 10/15..Train loss : 2.427..Validation loss : 1.250..Test accuracy : 0.658
# Epoch : 10/15..Train loss : 2.535..Validation loss : 1.280..Test accuracy : 0.659
# Epoch : 10/15..Train loss : 2.284..Validation loss : 1.346..Test accuracy : 0.630
# Epoch : 10/15..Train loss : 2.526..Validation loss : 1.379..Test accuracy : 0.631
# Epoch : 10/15..Train loss : 2.374..Validation loss : 1.370..Test accuracy : 0.648
# Epoch : 10/15..Train loss : 2.342..Validation loss : 1.380..Test accuracy : 0.632
# Epoch : 10/15..Train loss : 2.540..Validation loss : 1.328..Test accuracy : 0.656
# Epoch : 10/15..Train loss : 2.232..Validation loss : 1.273..Test accuracy : 0.661
# Epoch : 10/15..Train loss : 2.407..Validation loss : 1.321..Test accuracy : 0.659
# Epoch : 10/15..Train loss : 2.165..Validation loss : 1.391..Test accuracy : 0.637
# Epoch : 10/15..Train loss : 2.329..Validation loss : 1.372..Test accuracy : 0.643
# Epoch : 10/15..Train loss : 2.309..Validation loss : 1.303..Test accuracy : 0.655
# Epoch : 10/15..Train loss : 2.399..Validation loss : 1.316..Test accuracy : 0.659
# Epoch : 10/15..Train loss : 2.373..Validation loss : 1.370..Test accuracy : 0.645
# Epoch : 10/15..Train loss : 2.583..Validation loss : 1.292..Test accuracy : 0.645
# Epoch : 10/15..Train loss : 2.389..Validation loss : 1.297..Test accuracy : 0.664
# Epoch : 11/15..Train loss : 2.331..Validation loss : 1.353..Test accuracy : 0.658
# Epoch : 11/15..Train loss : 2.237..Validation loss : 1.406..Test accuracy : 0.618
# Epoch : 11/15..Train loss : 2.307..Validation loss : 1.347..Test accuracy : 0.635
# Epoch : 11/15..Train loss : 2.320..Validation loss : 1.351..Test accuracy : 0.640
# Epoch : 11/15..Train loss : 2.511..Validation loss : 1.336..Test accuracy : 0.650
# Epoch : 11/15..Train loss : 2.229..Validation loss : 1.301..Test accuracy : 0.659
# Epoch : 11/15..Train loss : 2.186..Validation loss : 1.254..Test accuracy : 0.644
# Epoch : 11/15..Train loss : 2.443..Validation loss : 1.273..Test accuracy : 0.650
# Epoch : 11/15..Train loss : 2.291..Validation loss : 1.277..Test accuracy : 0.668
# Epoch : 11/15..Train loss : 2.222..Validation loss : 1.281..Test accuracy : 0.653
# Epoch : 11/15..Train loss : 2.388..Validation loss : 1.265..Test accuracy : 0.672
# Epoch : 11/15..Train loss : 2.347..Validation loss : 1.229..Test accuracy : 0.684
# Epoch : 11/15..Train loss : 1.969..Validation loss : 1.268..Test accuracy : 0.662
# Epoch : 11/15..Train loss : 2.413..Validation loss : 1.297..Test accuracy : 0.663
# Epoch : 11/15..Train loss : 2.154..Validation loss : 1.275..Test accuracy : 0.678
# Epoch : 11/15..Train loss : 2.228..Validation loss : 1.298..Test accuracy : 0.668
# Epoch : 11/15..Train loss : 2.136..Validation loss : 1.277..Test accuracy : 0.666
# Epoch : 11/15..Train loss : 2.222..Validation loss : 1.225..Test accuracy : 0.680
# Epoch : 11/15..Train loss : 2.434..Validation loss : 1.202..Test accuracy : 0.693
# Epoch : 11/15..Train loss : 2.227..Validation loss : 1.262..Test accuracy : 0.662
# Epoch : 12/15..Train loss : 2.434..Validation loss : 1.372..Test accuracy : 0.622
# Epoch : 12/15..Train loss : 2.215..Validation loss : 1.303..Test accuracy : 0.640
# Epoch : 12/15..Train loss : 2.295..Validation loss : 1.256..Test accuracy : 0.654
# Epoch : 12/15..Train loss : 2.256..Validation loss : 1.260..Test accuracy : 0.668
# Epoch : 12/15..Train loss : 2.310..Validation loss : 1.291..Test accuracy : 0.640
# Epoch : 12/15..Train loss : 2.264..Validation loss : 1.314..Test accuracy : 0.649
# Epoch : 12/15..Train loss : 2.160..Validation loss : 1.294..Test accuracy : 0.660
# Epoch : 12/15..Train loss : 2.196..Validation loss : 1.276..Test accuracy : 0.665
# Epoch : 12/15..Train loss : 2.189..Validation loss : 1.291..Test accuracy : 0.640
# Epoch : 12/15..Train loss : 2.452..Validation loss : 1.249..Test accuracy : 0.682
# Epoch : 12/15..Train loss : 2.340..Validation loss : 1.287..Test accuracy : 0.670
# Epoch : 12/15..Train loss : 1.910..Validation loss : 1.288..Test accuracy : 0.667
# Epoch : 12/15..Train loss : 2.637..Validation loss : 1.257..Test accuracy : 0.675
# Epoch : 12/15..Train loss : 2.259..Validation loss : 1.293..Test accuracy : 0.655
# Epoch : 12/15..Train loss : 2.314..Validation loss : 1.314..Test accuracy : 0.648
# Epoch : 12/15..Train loss : 2.309..Validation loss : 1.304..Test accuracy : 0.666
# Epoch : 12/15..Train loss : 2.290..Validation loss : 1.287..Test accuracy : 0.678
# Epoch : 12/15..Train loss : 2.475..Validation loss : 1.298..Test accuracy : 0.675
# Epoch : 12/15..Train loss : 2.367..Validation loss : 1.287..Test accuracy : 0.662
# Epoch : 12/15..Train loss : 2.054..Validation loss : 1.303..Test accuracy : 0.666
# Epoch : 12/15..Train loss : 2.550..Validation loss : 1.269..Test accuracy : 0.654
# Epoch : 13/15..Train loss : 2.442..Validation loss : 1.279..Test accuracy : 0.668
# Epoch : 13/15..Train loss : 2.451..Validation loss : 1.364..Test accuracy : 0.649
# Epoch : 13/15..Train loss : 2.395..Validation loss : 1.344..Test accuracy : 0.657
# Epoch : 13/15..Train loss : 2.451..Validation loss : 1.280..Test accuracy : 0.669
# Epoch : 13/15..Train loss : 2.243..Validation loss : 1.298..Test accuracy : 0.677
# Epoch : 13/15..Train loss : 2.412..Validation loss : 1.266..Test accuracy : 0.690
# Epoch : 13/15..Train loss : 2.234..Validation loss : 1.268..Test accuracy : 0.684
# Epoch : 13/15..Train loss : 2.253..Validation loss : 1.225..Test accuracy : 0.674
# Epoch : 13/15..Train loss : 2.220..Validation loss : 1.211..Test accuracy : 0.683
# Epoch : 13/15..Train loss : 2.346..Validation loss : 1.249..Test accuracy : 0.665
# Epoch : 13/15..Train loss : 2.094..Validation loss : 1.244..Test accuracy : 0.677
# Epoch : 13/15..Train loss : 2.181..Validation loss : 1.260..Test accuracy : 0.663
# Epoch : 13/15..Train loss : 2.315..Validation loss : 1.278..Test accuracy : 0.674
# Epoch : 13/15..Train loss : 2.426..Validation loss : 1.337..Test accuracy : 0.654
# Epoch : 13/15..Train loss : 2.211..Validation loss : 1.369..Test accuracy : 0.646
# Epoch : 13/15..Train loss : 2.398..Validation loss : 1.284..Test accuracy : 0.673
# Epoch : 13/15..Train loss : 2.419..Validation loss : 1.213..Test accuracy : 0.701
# Epoch : 13/15..Train loss : 2.376..Validation loss : 1.262..Test accuracy : 0.696
# Epoch : 13/15..Train loss : 2.384..Validation loss : 1.281..Test accuracy : 0.680
# Epoch : 13/15..Train loss : 2.412..Validation loss : 1.214..Test accuracy : 0.679
# Epoch : 14/15..Train loss : 2.152..Validation loss : 1.210..Test accuracy : 0.668
# Epoch : 14/15..Train loss : 2.450..Validation loss : 1.254..Test accuracy : 0.651
# Epoch : 14/15..Train loss : 2.386..Validation loss : 1.217..Test accuracy : 0.671
# Epoch : 14/15..Train loss : 2.310..Validation loss : 1.251..Test accuracy : 0.664
# Epoch : 14/15..Train loss : 2.277..Validation loss : 1.327..Test accuracy : 0.638
# Epoch : 14/15..Train loss : 2.371..Validation loss : 1.344..Test accuracy : 0.650
# Epoch : 14/15..Train loss : 2.187..Validation loss : 1.248..Test accuracy : 0.658
# Epoch : 14/15..Train loss : 2.325..Validation loss : 1.199..Test accuracy : 0.669
# Epoch : 14/15..Train loss : 2.319..Validation loss : 1.205..Test accuracy : 0.674
# Epoch : 14/15..Train loss : 2.300..Validation loss : 1.234..Test accuracy : 0.688
# Epoch : 14/15..Train loss : 2.271..Validation loss : 1.236..Test accuracy : 0.680
# Epoch : 14/15..Train loss : 2.469..Validation loss : 1.205..Test accuracy : 0.686
# Epoch : 14/15..Train loss : 2.077..Validation loss : 1.222..Test accuracy : 0.686
# Epoch : 14/15..Train loss : 2.328..Validation loss : 1.174..Test accuracy : 0.695
# Epoch : 14/15..Train loss : 2.256..Validation loss : 1.190..Test accuracy : 0.700
# Epoch : 14/15..Train loss : 1.909..Validation loss : 1.186..Test accuracy : 0.692
# Epoch : 14/15..Train loss : 2.058..Validation loss : 1.199..Test accuracy : 0.686
# Epoch : 14/15..Train loss : 2.497..Validation loss : 1.196..Test accuracy : 0.683
# Epoch : 14/15..Train loss : 2.294..Validation loss : 1.176..Test accuracy : 0.703
# Epoch : 14/15..Train loss : 2.025..Validation loss : 1.163..Test accuracy : 0.707
# Epoch : 14/15..Train loss : 2.035..Validation loss : 1.163..Test accuracy : 0.702
# Epoch : 15/15..Train loss : 1.896..Validation loss : 1.209..Test accuracy : 0.680
# Epoch : 15/15..Train loss : 2.203..Validation loss : 1.202..Test accuracy : 0.689
# Epoch : 15/15..Train loss : 2.081..Validation loss : 1.204..Test accuracy : 0.677
# Epoch : 15/15..Train loss : 2.181..Validation loss : 1.219..Test accuracy : 0.675
# Epoch : 15/15..Train loss : 2.328..Validation loss : 1.235..Test accuracy : 0.670
# Epoch : 15/15..Train loss : 2.213..Validation loss : 1.190..Test accuracy : 0.674
# Epoch : 15/15..Train loss : 2.212..Validation loss : 1.148..Test accuracy : 0.676
# Epoch : 15/15..Train loss : 2.185..Validation loss : 1.168..Test accuracy : 0.692
# Epoch : 15/15..Train loss : 2.148..Validation loss : 1.239..Test accuracy : 0.692
# Epoch : 15/15..Train loss : 2.054..Validation loss : 1.242..Test accuracy : 0.689
# Epoch : 15/15..Train loss : 2.374..Validation loss : 1.230..Test accuracy : 0.685
# Epoch : 15/15..Train loss : 2.259..Validation loss : 1.198..Test accuracy : 0.691
# Epoch : 15/15..Train loss : 2.172..Validation loss : 1.215..Test accuracy : 0.677
# Epoch : 15/15..Train loss : 2.330..Validation loss : 1.184..Test accuracy : 0.687
# Epoch : 15/15..Train loss : 2.287..Validation loss : 1.192..Test accuracy : 0.697
# Epoch : 15/15..Train loss : 2.162..Validation loss : 1.158..Test accuracy : 0.698
# Epoch : 15/15..Train loss : 2.062..Validation loss : 1.150..Test accuracy : 0.695
# Epoch : 15/15..Train loss : 2.215..Validation loss : 1.158..Test accuracy : 0.695
# Epoch : 15/15..Train loss : 1.981..Validation loss : 1.187..Test accuracy : 0.684
# Epoch : 15/15..Train loss : 2.481..Validation loss : 1.166..Test accuracy : 0.701
# Epoch : 15/15..Train loss : 2.051..Validation loss : 1.132..Test accuracy : 0.708

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
checkpoint = {
              'state_dict' : model.state_dict(),
              'optimizer' : optimizer.state_dict(),
              'images_train' : train_data.class_to_idx,
              'classifier' : model.classifier,
              'epoch' : epochs
}
torch.save(checkpoint,'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load_checkpoint(filepath) :
    checkpoint = torch.load('checkpoint.pth')
    model = models.vgg16(pretrained = True)
    for param in model.parameters() :
        param.requires_grad = False
    model.classifier = checkpoint['classifier']
    model.load_state_dict(checkpoint['state_dict'])
    model.epochs = checkpoint['epoch']
    optimizer.load_state_dict(checkpoint['optimizer'])
    model.class_to_idx = train_data.class_to_idx
    return model
model = load_checkpoint('checkpoint.pth')

model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (fc1): Linear(in_features=25088, out_features=4096, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.3)
#     (fc2): Linear(in_features=4096, out_features=4096, bias=True)
#     (relu2): ReLU()
#     (dropout2): Dropout(p=0.3)
#     (fc3): Linear(in_features=4096, out_features=1000, bias=True)
#     (relu3): ReLU()
#     (droupout3): Dropout(p=0.3)
#     (fc4): Linear(in_features=1000, out_features=102, bias=True)
#     (output): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    
    # TODO: Process a PIL image for use in a PyTorch model
    im =Image.open(image)
    transform = transforms.Compose([transforms.Resize(256),
                                     transforms.CenterCrop(224),
                                     transforms.ToTensor(),
                                     transforms.Normalize([0.485, 0.456, 0.406],
                                                          [0.229, 0.224, 0.225])])
    np_image = np.array(transform(im))

    return np_image

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
image_path = data_dir + '/test' + '/100' + '/image_07896.jpg'
test = process_image(image_path)
imshow(test, ax=None, title=None)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, filepath, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    model = load_checkpoint(filepath)
    model.to('cpu')
    model.eval();
    image_tensor = torch.from_numpy(process_image(image_path)).type(torch.FloatTensor).\
    unsqueeze_(dim=0).to('cpu')
    log_ps = model.forward(image_tensor)
    ps = torch.exp(log_ps)
    top_p = (ps.topk(topk,dim=1)[0].detach().numpy())[0]
    top_class = (ps.topk(topk,dim=1)[1].detach().numpy())[0]
    prob,name = [],[]
    for i in top_p :
        prob.append(i)
    for i in top_class :
        name.append(i)
    prob_name = dict()
    for i in range(len(name)) :
        prob_name[name[i]] = prob[i]
    prob_name = dict(sorted(prob_name.items(),key=lambda item:item[1],reverse = True))
    prob,name = [],[]
    for i in prob_name.keys() :
        name.append(i)
    for i in prob_name.values() :
        prob.append(i)    
    return prob,name

# TODO: Implement the code to predict the class from an image file
predict(image_path, 'checkpoint.pth', topk=5)
# Out:
# ([0.011194433, 0.011150737, 0.011064009, 0.010856051, 0.010854457],
#  [44, 85, 52, 69, 45])

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
prob,name = predict(image_path, 'checkpoint.pth', topk=5)

# %%
image_path = data_dir + '/test' + '/100' + '/image_07939.jpg'
prob,flower_class = predict(image_path, 'checkpoint.pth', topk=5)
name = []
for i in flower_class :
    name.append(cat_to_name[i.astype(str)])
name
# Out:
# ['windflower',
#  'poinsettia',
#  'fritillary',
#  'japanese anemone',
#  'pink-yellow dahlia']

# %%
def show_result(image_path,prob,name):
    from PIL import Image
    im =Image.open(image_path)
    f,ax = plt.subplots(2,figsize=(8,8))
    f.suptitle(name[0])
    ax[0].imshow(im)
    ax[1].barh(name,prob)

show_result(image_path,prob,name)
